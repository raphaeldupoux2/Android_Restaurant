# %% [markdown]
# <a href="https://colab.research.google.com/github/raphaeldupoux2/Android_Restaurant/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projet sur la prédiction de la qualité du vin en fonction des caractéristiques chimiques d'un vin.
#
# Utilisation du dataset des vins : https://www.kaggle.com/datasets/shelvigarg/wine-quality-dataset
#
# 6497 vins avec les caractéristiques suivantes :
# type,fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,quality

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
print("Tensorflow version:", tf.__version__)
# Keras API reference: https://keras.io/api/
# Out:
# Tensorflow version: 2.15.0

# %%
from google.colab import files
uploadedFiles = files.upload()
# Out:
#      <input type="file" id="files-f4e1c4e4-eaf6-468e-b1d6-6a8149a1378d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4e1c4e4-eaf6-468e-b1d6-6a8149a1378d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas
df = pandas.read_csv("winequalityN (3).csv")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
# On mélange d'abord le dataset car il est trié en fonction des types de vins
df_melange = df.sample(frac=1).reset_index(drop=True)
df_melange
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            8.2              0.29         0.33            9.10
# 1     white            6.8              0.21         0.42            1.20
# 2       red            9.9              0.54         0.45            2.30
# 3     white            6.6              0.37         0.47            6.50
# 4     white            5.8              0.28         0.30            1.50
# ...     ...            ...               ...          ...             ...
# 6492  white            8.3              0.28         0.45            7.80
# 6493  white            6.8              0.28         0.43            7.60
# 6494  white            7.0              0.30         0.28            2.20
# 6495    red           10.4              0.44         0.73            6.55
# 6496    red            6.8              0.81         0.05            2.00
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df_sans_nan = df_melange.dropna()
df_sans_nan
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            8.2              0.29         0.33            9.10
# 1     white            6.8              0.21         0.42            1.20
# 2       red            9.9              0.54         0.45            2.30
# 3     white            6.6              0.37         0.47            6.50
# 4     white            5.8              0.28         0.30            1.50
# ...     ...            ...               ...          ...             ...
# 6492  white            8.3              0.28         0.45            7.80
# 6493  white            6.8              0.28         0.43            7.60
# 6494  white            7.0              0.30         0.28            2.20
# 6495    red           10.4              0.44         0.73            6.55
# 6496    red            6.8              0.81         0.05            2.00
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df_type_bin = df_sans_nan
df_type_bin.loc[:, 'type'] = df_type_bin['type'].replace({'red': 1, 'white': 0})
df_type_bin
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       0            8.2              0.29         0.33            9.10
# 1       0            6.8              0.21         0.42            1.20
# 2       1            9.9              0.54         0.45            2.30
# 3       0            6.6              0.37         0.47            6.50
# 4       0            5.8              0.28         0.30            1.50
# ...   ...            ...               ...          ...             ...
# 6492    0            8.3              0.28         0.45            7.80
# 6493    0            6.8              0.28         0.43            7.60
# 6494    0            7.0              0.30         0.28            2.20
# 6495    1           10.4              0.44         0.73            6.55
# 6496    1            6.8              0.81         0.05            2.00
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df_valeurs_normalisées = df_type_bin
colonnes_a_normaliser = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']

# Normalise les données entre 0 et 1
df_valeurs_normalisées.loc[:, colonnes_a_normaliser] = (df[colonnes_a_normaliser] - df[colonnes_a_normaliser].min()) / (df[colonnes_a_normaliser].max() - df[colonnes_a_normaliser].min())
df_valeurs_normalisées
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       0       0.264463          0.126667     0.216867        0.308282
# 1       0       0.206612          0.146667     0.204819        0.015337
# 2       1       0.355372          0.133333     0.240964        0.096626
# 3       0       0.280992          0.100000     0.192771        0.121166
# 4       0       0.280992          0.100000     0.192771        0.121166
# ...   ...            ...               ...          ...             ...
# 6492    0       0.198347          0.346667     0.048193        0.021472
# 6493    0       0.173554          0.313333     0.060241        0.024540
# 6494    0       0.206612          0.286667     0.078313        0.026074
# 6495    1       0.173554          0.376667     0.072289        0.021472
# 6496    1       0.181818          0.153333     0.283133        0.046012
#
#       chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# ...

# %%
df_valeurs_normalisées['quality']

quality_column = df_valeurs_normalisées['quality']

# Supprime la colonne "quality" de la dataframe principale
df_x = df_valeurs_normalisées.drop(columns=['quality'])
df_x
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       0       0.264463          0.126667     0.216867        0.308282
# 1       0       0.206612          0.146667     0.204819        0.015337
# 2       1       0.355372          0.133333     0.240964        0.096626
# 3       1       0.280992          0.100000     0.192771        0.121166
# 4       1       0.280992          0.100000     0.192771        0.121166
# ...   ...            ...               ...          ...             ...
# 6492    0       0.198347          0.346667     0.048193        0.021472
# 6493    0       0.173554          0.313333     0.060241        0.024540
# 6494    0       0.206612          0.286667     0.078313        0.026074
# ...

# %%
# Découpage train/validation
split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]
print('Split:', len(x_train), 'vs', len(x_valid))

# %%
# affichage des  premières données
print('First time step:', time_step[:10])
print('First sunspots means:', sunspots[:10])
print('Samples number:', len(sunspots))

# %%
# Construire le modèle
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(11,)),  # 11 caractéristiques en entrée
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)  # Sortie de dimension 1 pour la qualité du vin
])

# %%
# Compiler le modèle
model.compile(optimizer='adam',
              loss='mean_squared_error',  # Parce que c'est un problème de régression
              metrics=['mean_absolute_error'])

# %%
# Entraîner le modèle
history = model.fit(train_features, train_labels, epochs=100, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-32843dd82035> in <cell line: 2>()
#       1 # Entraîner le modèle
# ----> 2 history = model.fit(train_features, train_labels, epochs=100, validation_split=0.2)
#
# NameError: name 'train_features' is not defined

# %%
# Évaluer le modèle
loss, mae = model.evaluate(test_features, test_labels)
print("Mean Absolute Error:", mae)

# %%
# Tracer l'erreur de validation au fil des époques
plt.plot(history.history['mean_absolute_error'], label='Mean Absolute Error')
plt.plot(history.history['val_mean_absolute_error'], label = 'Val Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(loc='upper right')
plt.show()
